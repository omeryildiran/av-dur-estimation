# %%
from fitMain import *

# %%
dataName = "IP_mainExpAvDurEstimate_2025-05-30_11h21.09.224.csv"
data, sensoryVar, standardVar, conflictVar, uniqueSensory, uniqueStandard, uniqueConflict, nLambda, nSigma, nMu = loadData(dataName,isShared=False)
print("sensoryVar:", sensoryVar)
global sharedSigma
sharedSigma=False

fit = fitMultipleStartingPoints(data, nStart=5)
# Out:
# uniqueSensory: [1.2 0.1]
#  uniqueStandard: [0.5]
#  uniqueConflict: [-0.251, 0.084]
# sensoryVar: audNoise
# Fitting multiple starting points:   1%|          | 1/125 [00:00<00:38,  3.19it/s]
#  len initGuesses: 9
#  len initGuesses: 9
# Fitting multiple starting points:   2%|▏         | 2/125 [00:03<03:41,  1.80s/it]
#  len initGuesses: 9
# Fitting multiple starting points:   2%|▏         | 3/125 [00:06<04:46,  2.35s/it]
#  len initGuesses: 9
# Fitting multiple starting points:   2%|▏         | 3/125 [00:07<05:15,  2.58s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 7
#       4 global sharedSigma
#       5 sharedSigma=False
# ----> 7 fit = fitMultipleStartingPoints(data, nStart=5)
#
# File ~/Library/CloudStorage/GoogleDrive-omerulfaruk97@gmail.com/My Drive/MyReposDrive/obsidian_Notes/Landy Omer Re 1/av-dur-estimation/fitMain.py:386, in fitMultipleStartingPoints(data, nStart)
#     382     disable=True
#     384 for i in tqdm(range(len(multipleInitGuesses)), desc="Fitting multiple starting points",disable=disable):
# --> 386     fit = fitJoint(groupedData, initGuesses=multipleInitGuesses[i])
#     387     nll = nLLJoint(fit.x, levels, responses, totalResp, conflictLevels, noiseLevels)
#     389     if nll < best_nll:
#
# File ~/Library/CloudStorage/GoogleDrive-omerulfaruk97@gmail.com/My Drive/MyReposDrive/obsidian_Notes/Landy Omer Re 1/av-dur-estimation/fitMain.py:326, in fitJoint(grouped_data, initGuesses)
#     323 print(f" len initGuesses: {len(initGuesses)}")
#     325 # Minimize negative log-likelihood
# --> 326 result = minimize(
#     327     nLLJoint,
#     328     x0=initGuesses,
#     329     args=(intensities, chose_tests, total_responses, conflicts, noise_levels),
#     330     bounds=bounds,
#     331     method='L-BFGS-B'  # Use L-BFGS-B for bounded optimization
#     332 )
#     334 return result
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_minimize.py:731, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     728     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     729                              **options)
#     730 elif meth == 'l-bfgs-b':
# --> 731     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     732                            callback=callback, **options)
#     733 elif meth == 'tnc':
#     734     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     735                         **options)
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_lbfgsb_py.py:407, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     401 task_str = task.tobytes()
#     402 if task_str.startswith(b'FG'):
#     403     # The minimization routine wants f and g at the current x.
#     404     # Note that interruptions due to maxfun are postponed
#     405     # until the completion of the current minimization iteration.
#     406     # Overwrite f and g:
# --> 407     f, g = func_and_grad(x)
#     408 elif task_str.startswith(b'NEW_X'):
#     409     # new iteration
#     410     n_iterations += 1
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:344, in ScalarFunction.fun_and_grad(self, x)
#     342     self._update_x(x)
#     343 self._update_fun()
# --> 344 self._update_grad()
#     345 return self.f, self.g
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:306, in ScalarFunction._update_grad(self)
#     304 if self._orig_grad in FD_METHODS:
#     305     self._update_fun()
# --> 306 self.g = self._wrapped_grad(self.x, f0=self.f)
#     307 self.g_updated = True
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:47, in _wrapper_grad.<locals>.wrapped1(x, f0)
#      45 def wrapped1(x, f0=None):
#      46     ncalls[0] += 1
# ---> 47     return approx_derivative(
#      48         fun, x, f0=f0, **finite_diff_options
#      49     )
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:519, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     516     use_one_sided = False
#     518 if sparsity is None:
# --> 519     return _dense_difference(fun_wrapped, x0, f0, h,
#     520                              use_one_sided, method)
#     521 else:
#     522     if not issparse(sparsity) and len(sparsity) == 2:
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:592, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     590     x1[i] += h[i]
#     591     dx = x1[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 592     df = fun(x1) - f0
#     593 elif method == '3-point' and use_one_sided[i]:
#     594     x1[i] += h[i]
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:470, in approx_derivative.<locals>.fun_wrapped(x)
#     467 if xp.isdtype(x.dtype, "real floating"):
#     468     x = xp.astype(x, x0.dtype)
# --> 470 f = np.atleast_1d(fun(x, *args, **kwargs))
#     471 if f.ndim > 1:
#     472     raise RuntimeError("`fun` return value has "
#     473                        "more than 1 dimension.")
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:20, in _wrapper_fun.<locals>.wrapped(x)
#      16 ncalls[0] += 1
#      17 # Send a copy because the user may overwrite it.
#      18 # Overwriting results in undefined behaviour because
#      19 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 20 fx = fun(np.copy(x), *args)
#      21 # Make sure the function returns a true scalar
#      22 if not np.isscalar(fx):
#
# File ~/Library/CloudStorage/GoogleDrive-omerulfaruk97@gmail.com/My Drive/MyReposDrive/obsidian_Notes/Landy Omer Re 1/av-dur-estimation/fitMain.py:269, in nLLJoint(params, delta_dur, responses, total_responses, conflicts, noise_levels)
#     266 lambda_, mu, sigma = getParams(params, conflict, audio_noise, nLambda, nSigma)
#     268 # Calculate probability of choosing test
# --> 269 p = psychometric_function(x, lambda_, mu, sigma)
#     271 # Avoid numerical issues
#     272 epsilon = 1e-9
#
# File ~/Library/CloudStorage/GoogleDrive-omerulfaruk97@gmail.com/My Drive/MyReposDrive/obsidian_Notes/Landy Omer Re 1/av-dur-estimation/fitMain.py:213, in psychometric_function(x, lambda_, mu, sigma)
#     211 def psychometric_function(x, lambda_, mu, sigma):
#     212     # Cumulative distribution function with mean mu and standard deviation sigma
# --> 213     cdf = norm.cdf(x, loc=mu, scale=sigma)
#     214     # take into account of lapse rate and return the probability of choosing test
#     215     p = lambda_/2 + (1-lambda_) * norm.cdf((x - mu) / sigma)
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/stats/_distn_infrastructure.py:2112, in rv_continuous.cdf(self, x, *args, **kwds)
#    2110 x = np.asarray((x - loc)/scale, dtype=dtyp)
#    2111 cond0 = self._argcheck(*args) & (scale > 0)
# -> 2112 cond1 = self._open_support_mask(x, *args) & (scale > 0)
#    2113 cond2 = (x >= np.asarray(_b)) & cond0
#    2114 cond = cond0 & cond1
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/stats/_distn_infrastructure.py:1023, in rv_generic._open_support_mask(self, x, *args)
#    1021 def _open_support_mask(self, x, *args):
#    1022     a, b = self._get_support(*args)
# -> 1023     with np.errstate(invalid='ignore'):
#    1024         return (a < x) & (x < b)
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/numpy/core/_ufunc_config.py:436, in errstate.__exit__(self, *exc_info)
#     435 def __exit__(self, *exc_info):
# --> 436     seterr(**self.oldstate)
#     437     if self.call is not _Unspecified:
#     438         seterrcall(self.oldcall)
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/numpy/core/_ufunc_config.py:128, in seterr(all, divide, over, under, invalid)
#     122 maskvalue = ((_errdict[divide] << SHIFT_DIVIDEBYZERO) +
#     123              (_errdict[over] << SHIFT_OVERFLOW) +
#     124              (_errdict[under] << SHIFT_UNDERFLOW) +
#     125              (_errdict[invalid] << SHIFT_INVALID))
#     127 pyvals[1] = maskvalue
# --> 128 umath.seterrobj(pyvals)
#     129 return old
#
# KeyboardInterrupt:

# %%
data
# Out:
#      Unnamed: 0  standardDur  audNoise  order   preDur  postDur   isiDur  \
# 0             0          0.5       1.2      2  0.45116  0.22558  0.76864
# 1             1          0.5       1.2      1  0.35926  0.26735  0.68509
# 2             2          0.5       0.1      2  0.41774  0.24229  0.56813
# 3             3          0.5       0.1      1  0.27571  0.34255  0.60990
# 4             4          0.5       1.2      1  0.29242  0.40103  0.71016
# ..          ...          ...       ...    ...      ...      ...      ...
# 611         611          0.5       0.1      2  0.36761  0.35090  0.48458
# 612         612          0.5       1.2      2  0.24229  0.40103  0.67674
# 613         613          0.5       1.2      1  0.39267  0.28406  0.78535
# 614         614          0.5       0.1      2  0.28406  0.30077  0.66838
# 615         615          0.5       0.1      1  0.33419  0.28406  0.44280
#
#      trial_num  totalDur  delta_dur_percents  ...  recordedDurVisualTest  \
# 0            0   2.77379                0.65  ...                 0.7327
# 1            1   1.98844               -0.65  ...                 0.3589
# 2            2   2.55657                0.65  ...                 0.7833
# 3            3   1.90490               -0.65  ...                 0.2499
# 4            4   2.85734                0.90  ...                 1.1329
# ..         ...       ...                 ...  ...                    ...
# 611        611   2.36441                0.32  ...                 0.6169
# 612        612   2.48138                0.32  ...                 0.5659
# 613        613   2.60669                0.29  ...                 0.8249
# 614        614   2.41453                0.32  ...                 0.6166
# 615        615   2.22237                0.32  ...                 0.7340
#
#      recordedOnsetVisualStandard  recordedOffsetVisualStandard  \
# 0                         0.3200                        1.0863
# 1                         1.3367                        1.7709
# 2                         0.3430                        1.0011
# 3                         1.1887                        1.5144
# 4                         1.9069                        2.6738
# ..                           ...                           ...
# 611                       0.4545                        0.7796
# 612                       0.1075                        0.8743
# 613                       1.9372                        2.3705
# 614                       0.2076                        0.8659
# 615                       1.5687                        1.8940
#
#     recordedDurVisualStandard  modalityCue  chose_test  chose_standard  \
# 0                      0.7663            A           1               0
# 1                      0.4343            A           0               1
# 2                      0.6581            A           1               0
# 3                      0.3256            A           0               1
# 4                      0.7670            A           1               0
# ..                        ...          ...         ...             ...
# 611                    0.3252            A           1               0
# 612                    0.7668            A           1               0
# 613                    0.4333            A           0               1
# 614                    0.6583            A           1               0
# 615                    0.3253            A           1               0
#
#      visualPSEBias  standard_dur riseDur
# 0           0.1823           0.5       1
# 1           0.1853           0.5       1
# 2           0.0741           0.5       1
# 3           0.0766           0.5       1
# 4           0.1830           0.5       1
# ..             ...           ...     ...
# 611         0.0762           0.5       1
# 612         0.1828           0.5       1
# 613         0.1843           0.5       1
# 614         0.0743           0.5       1
# 615         0.0763           0.5       1
#
# [616 rows x 33 columns]

# %%
print(f"Fitted parameters: {fit.x}")
# Out:
# Fitted parameters: [0.25       0.02096811 0.11105286 0.06856401 0.05872193 0.42500997
#  0.13503106 0.25681932 0.25610026]

# %%
# Plot the fitted psychometric functions
plot_fitted_psychometric(
    data, fit, nLambda, nSigma, uniqueSensory, uniqueStandard, uniqueConflict,
    standardVar, sensoryVar, conflictVar, intensityVariable
)
# Out:
# standardLevel: 0.5, audioNoiseLevel: 1.2, uniqueConflict: [-0.251, 0.084]
# Noise: 1.2, Conflict: -0.251, Mu: 0.021, Sigma: 0.425
# Noise: 1.2, Conflict: 0.084, Mu: 0.111, Sigma: 0.135
# standardLevel: 0.5, audioNoiseLevel: 0.1, uniqueConflict: [-0.251, 0.084]
# Noise: 0.1, Conflict: -0.251, Mu: 0.111, Sigma: 0.135
# Noise: 0.1, Conflict: 0.084, Mu: 0.059, Sigma: 0.256

# %%
breakss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 breakss
#
# NameError: name 'breakss' is not defined

# %%
# Plot the relation between conflict and PSE (mu) with confidence intervals
allBootedFits = paramBootstrap(fit.x, nBoots=100)
plot_conflict_vs_pse(fit, allBootedFits)
# Out:
# Grouping by delta_dur_percents, audNoise, standardDur, conflictDur
# Bootstrapping:   0%|          | 0/100 [00:00<?, ?iteration/s]
#  len initGuesses: 9
# Bootstrapping:   1%|          | 1/100 [00:01<01:59,  1.20s/iteration]
#  len initGuesses: 9
# Bootstrapping:   2%|▏         | 2/100 [00:02<01:55,  1.18s/iteration]
#  len initGuesses: 9
# Bootstrapping:   2%|▏         | 2/100 [00:02<02:10,  1.33s/iteration]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Plot the relation between conflict and PSE (mu) with confidence intervals
# ----> 2 allBootedFits = paramBootstrap(fit.x, nBoots=100)
#       3 plot_conflict_vs_pse(fit, allBootedFits)
#
# File ~/Library/CloudStorage/GoogleDrive-omerulfaruk97@gmail.com/My Drive/MyReposDrive/obsidian_Notes/Landy Omer Re 1/av-dur-estimation/fitMain.py:482, in paramBootstrap(fitParams, nBoots)
#     478 initGuessEstimate = estimate_initial_guesses(simData[intensityVariable].values,
#     479                                             simData['num_of_chose_test'],
#     480                                             simData['total_responses'])
#     481 # fit the data to boot
# --> 482 bootFit = fitJoint(grouped_data=simData, initGuesses=initGuessEstimate)
#     484 # save
#     485 nBootParams.append(bootFit.x)
#
# File ~/Library/CloudStorage/GoogleDrive-omerulfaruk97@gmail.com/My Drive/MyReposDrive/obsidian_Notes/Landy Omer Re 1/av-dur-estimation/fitMain.py:326, in fitJoint(grouped_data, initGuesses)
#     323 print(f" len initGuesses: {len(initGuesses)}")
#     325 # Minimize negative log-likelihood
# --> 326 result = minimize(
#     327     nLLJoint,
#     328     x0=initGuesses,
#     329     args=(intensities, chose_tests, total_responses, conflicts, noise_levels),
#     330     bounds=bounds,
#     331     method='L-BFGS-B'  # Use L-BFGS-B for bounded optimization
#     332 )
#     334 return result
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_minimize.py:731, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     728     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     729                              **options)
#     730 elif meth == 'l-bfgs-b':
# --> 731     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     732                            callback=callback, **options)
#     733 elif meth == 'tnc':
#     734     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     735                         **options)
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_lbfgsb_py.py:407, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     401 task_str = task.tobytes()
#     402 if task_str.startswith(b'FG'):
#     403     # The minimization routine wants f and g at the current x.
#     404     # Note that interruptions due to maxfun are postponed
#     405     # until the completion of the current minimization iteration.
#     406     # Overwrite f and g:
# --> 407     f, g = func_and_grad(x)
#     408 elif task_str.startswith(b'NEW_X'):
#     409     # new iteration
#     410     n_iterations += 1
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:344, in ScalarFunction.fun_and_grad(self, x)
#     342     self._update_x(x)
#     343 self._update_fun()
# --> 344 self._update_grad()
#     345 return self.f, self.g
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:306, in ScalarFunction._update_grad(self)
#     304 if self._orig_grad in FD_METHODS:
#     305     self._update_fun()
# --> 306 self.g = self._wrapped_grad(self.x, f0=self.f)
#     307 self.g_updated = True
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:47, in _wrapper_grad.<locals>.wrapped1(x, f0)
#      45 def wrapped1(x, f0=None):
#      46     ncalls[0] += 1
# ---> 47     return approx_derivative(
#      48         fun, x, f0=f0, **finite_diff_options
#      49     )
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:519, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     516     use_one_sided = False
#     518 if sparsity is None:
# --> 519     return _dense_difference(fun_wrapped, x0, f0, h,
#     520                              use_one_sided, method)
#     521 else:
#     522     if not issparse(sparsity) and len(sparsity) == 2:
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:592, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     590     x1[i] += h[i]
#     591     dx = x1[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 592     df = fun(x1) - f0
#     593 elif method == '3-point' and use_one_sided[i]:
#     594     x1[i] += h[i]
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:470, in approx_derivative.<locals>.fun_wrapped(x)
#     467 if xp.isdtype(x.dtype, "real floating"):
#     468     x = xp.astype(x, x0.dtype)
# --> 470 f = np.atleast_1d(fun(x, *args, **kwargs))
#     471 if f.ndim > 1:
#     472     raise RuntimeError("`fun` return value has "
#     473                        "more than 1 dimension.")
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:20, in _wrapper_fun.<locals>.wrapped(x)
#      16 ncalls[0] += 1
#      17 # Send a copy because the user may overwrite it.
#      18 # Overwriting results in undefined behaviour because
#      19 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 20 fx = fun(np.copy(x), *args)
#      21 # Make sure the function returns a true scalar
#      22 if not np.isscalar(fx):
#
# File ~/Library/CloudStorage/GoogleDrive-omerulfaruk97@gmail.com/My Drive/MyReposDrive/obsidian_Notes/Landy Omer Re 1/av-dur-estimation/fitMain.py:269, in nLLJoint(params, delta_dur, responses, total_responses, conflicts, noise_levels)
#     266 lambda_, mu, sigma = getParams(params, conflict, audio_noise, nLambda, nSigma)
#     268 # Calculate probability of choosing test
# --> 269 p = psychometric_function(x, lambda_, mu, sigma)
#     271 # Avoid numerical issues
#     272 epsilon = 1e-9
#
# File ~/Library/CloudStorage/GoogleDrive-omerulfaruk97@gmail.com/My Drive/MyReposDrive/obsidian_Notes/Landy Omer Re 1/av-dur-estimation/fitMain.py:213, in psychometric_function(x, lambda_, mu, sigma)
#     211 def psychometric_function(x, lambda_, mu, sigma):
#     212     # Cumulative distribution function with mean mu and standard deviation sigma
# --> 213     cdf = norm.cdf(x, loc=mu, scale=sigma)
#     214     # take into account of lapse rate and return the probability of choosing test
#     215     p = lambda_/2 + (1-lambda_) * norm.cdf((x - mu) / sigma)
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/stats/_distn_infrastructure.py:2111, in rv_continuous.cdf(self, x, *args, **kwds)
#    2109 dtyp = np.promote_types(x.dtype, np.float64)
#    2110 x = np.asarray((x - loc)/scale, dtype=dtyp)
# -> 2111 cond0 = self._argcheck(*args) & (scale > 0)
#    2112 cond1 = self._open_support_mask(x, *args) & (scale > 0)
#    2113 cond2 = (x >= np.asarray(_b)) & cond0
#
# KeyboardInterrupt:
