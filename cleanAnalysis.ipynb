# %%
from fitMain import *

# %%
dataName = "HH_all.csv"#"all_all.csv"
data, sensoryVar, standardVar, conflictVar, uniqueSensory, uniqueStandard, uniqueConflict, nLambda, nSigma, nMu = loadData(dataName,isShared=False,isAllIndependent=True)
print("sensoryVar:", sensoryVar)
global sharedSigma
sharedSigma=False
global allIndependent
allIndependent=True

#fit = fitMultipleStartingPoints(data, nStart=1)
# Out:
#  Total trials before cleaning
# : 2504
# uniqueSensory: [1.2 0.1]
#  uniqueStandard: [0.5]
#  uniqueConflict: [-0.25, -0.17, -0.08, 0.0, 0.08, 0.17, 0.25]
#
# 545  trials with testDurSCheck False
# 13  trials with standardDurCheck False
#
# 545  trials with abs(testDurSCompare) > 0.05
# 13  trials with abs(standardDurCompare) > 0.05
#
# 545  trials with testDurSCheckBias False
# 0  trials with negative visual test duration
# 0  trials with negative visual standard duration
# testdurCompare > 0.05: 545 trials
# 0  trials with negative visual standard duration
# 0  trials with negative visual test duration
# total trials after cleaning: 1946
# sensoryVar: audNoise
# /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
data
# Out:
#       Unnamed: 0  standardDur  audNoise  order   preDur  postDur   isiDur  \
# 0              0          0.5       1.2      2  0.29881  0.25731  0.41501
# 1              1          0.5       1.2      2  0.22411  0.25731  0.58932
# 2              2          0.5       1.2      2  0.29051  0.29051  0.61422
# 3              3          0.5       1.2      2  0.25731  0.43161  0.77192
# 4              4          0.5       0.1      1  0.36521  0.25731  0.70552
# ...          ...          ...       ...    ...      ...      ...      ...
# 1941         913          0.5       1.2      1  0.30013  0.35016  0.57526
# 1942         914          0.5       1.2      2  0.21676  0.24177  0.56692
# 1943         918          0.5       1.2      1  0.25845  0.44186  0.75867
# 1944         919          0.5       1.2      2  0.30013  0.26679  0.71699
# 1945         920          0.5       1.2      1  0.37517  0.22510  0.53357
#
#       trial_num  totalDur  delta_dur_percents  ...  testDurSCheckBias  \
# 0             0   1.76796               -0.40  ...               True
# 1             1   2.11658                0.10  ...               True
# 2             2   2.63949                0.90  ...               True
# 3             3   2.25767               -0.40  ...               True
# 4             4   2.37388                0.10  ...               True
# ...         ...       ...                 ...  ...                ...
# 1941        913   2.11761               -0.22  ...               True
# 1942        914   1.91751               -0.22  ...               True
# 1943        918   2.35104               -0.22  ...               True
# 1944        919   2.19265               -0.18  ...               True
# 1945        920   2.02590               -0.22  ...               True
#
#       standardDurCheck  testDurSCompare standardDurCompare  standard_dur  \
# 0                 True          0.00229             0.0014           0.5
# 1                 True          0.00378             0.0014           0.5
# 2                 True          0.00567             0.0051           0.5
# 3                 True          0.00309             0.0014           0.5
# 4                 True          0.00082             0.0034           0.5
# ...                ...              ...                ...           ...
# 1941              True          0.00206             0.0013           0.5
# 1942              True          0.02546             0.0049           0.5
# 1943              True          0.00186             0.0020           0.5
# 1944              True          0.02658             0.0023           0.5
# 1945              True          0.00146             0.0058           0.5
#
#       riseDur  logStandardDur  logConflictDur  logTestDur logDeltaDur
# 0           1        6.214608        5.521461    5.699808   -0.514800
# 1           1        6.214608            -inf    6.305947    0.091339
# 2           1        6.214608             NaN    6.852486    0.637878
# 3           1        6.214608        5.521461    5.699808   -0.514800
# 4           1        6.214608            -inf    6.305947    0.091339
# ...       ...             ...             ...         ...         ...
# 1941        1        6.214608            -inf    5.970854   -0.243755
# 1942        1        6.214608             NaN    5.970854   -0.243755
# 1943        1        6.214608        5.521461    5.970854   -0.243755
# 1944        1        6.214608            -inf    6.012541   -0.202067
# 1945        1        6.214608             NaN    5.970854   -0.243755
#
# [1946 rows x 50 columns]

# %%
print(f"Fitted parameters: {fit.x}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(f"Fitted parameters: {fit.x}")
#
# NameError: name 'fit' is not defined

# %%
# Plot the fitted psychometric functions
plot_fitted_psychometric(
    data, fit, nLambda, nSigma, uniqueSensory, uniqueStandard, uniqueConflict,
    standardVar, sensoryVar, conflictVar, intensityVariable
)
#data, sensoryVar, standardVar, conflictVar, uniqueSensory, uniqueStandard, uniqueConflict, nLambda, nSigma, nMu
# Out:
# standardLevel: 0.5, audioNoiseLevel: 0.1, uniqueConflict: [-0.25, -0.17, -0.08, 0.0, 0.08, 0.17, 0.25]
# Noise: 0.1, Conflict: -0.25, Mu: -0.045, Sigma: 0.173
# Noise: 0.1, Conflict: -0.17, Mu: -0.025, Sigma: 0.134
# Noise: 0.1, Conflict: -0.08, Mu: -0.036, Sigma: 0.240
# Noise: 0.1, Conflict: 0.0, Mu: 0.017, Sigma: 0.172
# Noise: 0.1, Conflict: 0.08, Mu: 0.040, Sigma: 0.172
# Noise: 0.1, Conflict: 0.17, Mu: 0.037, Sigma: 0.174
# Noise: 0.1, Conflict: 0.25, Mu: 0.035, Sigma: 0.112
# standardLevel: 0.5, audioNoiseLevel: 1.2, uniqueConflict: [-0.25, -0.17, -0.08, 0.0, 0.08, 0.17, 0.25]
# Noise: 1.2, Conflict: -0.25, Mu: -0.448, Sigma: 0.242
# Noise: 1.2, Conflict: -0.17, Mu: -0.209, Sigma: 0.089
# Noise: 1.2, Conflict: -0.08, Mu: -0.087, Sigma: 0.248
# Noise: 1.2, Conflict: 0.0, Mu: 0.027, Sigma: 0.312
# Noise: 1.2, Conflict: 0.08, Mu: 0.105, Sigma: 0.251
# Noise: 1.2, Conflict: 0.17, Mu: 0.265, Sigma: 0.420
# Noise: 1.2, Conflict: 0.25, Mu: 0.212, Sigma: 0.329

# %%
# # dataName = "HH2_mainExpAvDurEstimate_2025-06-03_11h16.46.424.csv"
# # data, sensoryVar, standardVar, conflictVar, uniqueSensory, uniqueStandard, uniqueConflict, nLambda, nSigma, nMu = loadData(dataName,isShared=False)
# # fitB = fitMultipleStartingPoints(data, nStart=1)

# # plot_fitted_psychometric(
# #     data, fitA, nLambda, nSigma, uniqueSensory, uniqueStandard, uniqueConflict,
# #     standardVar, sensoryVar, conflictVar, intensityVariable
# # )

# plt.figure(figsize=(12*2.5, 6*2))

# def plot_fitted_psychometric_across_sessions(data, fit, nLambda, nSigma, uniqueSensory, uniqueStandard, uniqueConflict, standardVar, sensoryVar, conflictVar, intensityVariable):
#     import matplotlib.pyplot as plt
#     import numpy as np
#     colors=np.random.rand(len(uniqueConflict), 3)  # Random colors for each sensory level

#     # create plot within a single figure
#     #colors = sns.color_palette("viridis", n_colors=len(uniqueSensory))  # Use Set2 palette for different noise levels
#     for i, standardLevel in enumerate(uniqueStandard):
#         for j, audioNoiseLevel in enumerate(uniqueSensory):
#             print(f"standardLevel: {standardLevel}, audioNoiseLevel: {audioNoiseLevel}, uniqueConflict: {uniqueConflict}")
#             for k, conflictLevel in enumerate(uniqueConflict):
#                 lambda_, mu, sigma = getParams(fit.x, conflictLevel, audioNoiseLevel, nLambda, nSigma)
#                  # Filter the data for the current standard and audio noise levels
#                 df = data[round(data[standardVar], 2) == round(standardLevel,2)]
#                 df = df[df[sensoryVar] == audioNoiseLevel]
#                 df = df[df[conflictVar] == conflictLevel]
#                 dfFiltered = groupByChooseTest(df)
#                 levels = dfFiltered[intensityVariable].values
#                 if len(levels) == 0:
#                     continue
#                 responses = dfFiltered['num_of_chose_test'].values
#                 totalResponses = dfFiltered['total_responses'].values
                
#                 # Fit the psychometric function
#                 plt.subplot(1, 2, j+1)
#                 maxX = max(levels) + 0.1
#                 minX = min(levels) - 0.1
#                 x = np.linspace(-0.9, 0.9, 500)
#                 y = psychometric_function(x, lambda_, mu, sigma)
#                 #color=sns.color_palette("viridis", as_cmap=True)(k / len(uniqueConflict))  # Use a colormap for different conflict levels
#                 color= colors[k]
#                 plt.plot(x, y, color=color, label=f"Conflict: {int(conflictLevel*1000)}, mu: {mu:.3f}, $\sigma$: {sigma:.3f}", linewidth=4,)
#                 plt.axvline(x=0, color='gray', linestyle='--')
#                 plt.axhline(y=0.5, color='gray', linestyle='--')
#                 plt.xlabel(f"({intensityVariable}) Test(stair-a)-Standard(a) Duration Difference Ratio(%)")
#                 plt.ylabel("P(chose test)")
#                 #plt.title(f" {pltTitle} ", fontsize=16)

#                 plt.title(f"{pltTitle} AV,A Duration Comp. Noise: {audioNoiseLevel}", fontsize=16)
#                 plt.legend(fontsize=14, title_fontsize=14)
#                 plt.grid()
#                 bin_and_plot(dfFiltered, bin_method='cut', bins=10, plot=True, color=color)

#                 plt.text(0.05, 0.8, f"Shared $\lambda$: {lambda_:.2f}", fontsize=12, ha='left', va='top', transform=plt.gca().transAxes)
#                 #lt.tight_layout()
#                 plt.grid(True)

#                 # print the fitted parameters
#                 print(f"Noise: {audioNoiseLevel}, Conflict: {conflictLevel}, Mu: {mu:.3f}, Sigma: {sigma:.3f}")
#     #



        


# def loadAndPlot(dataName):
#     data, sensoryVar, standardVar, conflictVar, uniqueSensory, uniqueStandard, uniqueConflict, nLambda, nSigma, nMu = loadData(dataName,isShared=False)
#     fit = fitMultipleStartingPoints(data, nStart=1)
#     plot_fitted_psychometric_across_sessions(
#         data, fit, nLambda, nSigma, uniqueSensory, uniqueStandard, uniqueConflict,
#         standardVar, sensoryVar, conflictVar, intensityVariable
#     )
#     #plt.show()
# import random 
# random.seed(11)  # For reproducibility
# #session by session
# dataName = "HH_mainExpAvDurEstimate_2025-06-02_11h26.04.896.csv"
# loadAndPlot(dataName)
# dataName = "HH2_mainExpAvDurEstimate_2025-06-03_11h16.46.424.csv"
# loadAndPlot(dataName)
# dataName = "HH3_mainExpAvDurEstimate_2025-06-05_11h27.28.881.csv"
# loadAndPlot(dataName)

# %%
# Plot the relation between conflict and PSE (mu) with confidence intervals
allBootedFits = paramBootstrap(fit.x, nBoots=10)
# Out:
# Bootstrapping:  10%|█         | 1/10 [00:07<01:06,  7.34s/iteration]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Plot the relation between conflict and PSE (mu) with confidence intervals
# ----> 2 allBootedFits = paramBootstrap(fit.x, nBoots=10)
#
# File ~/Library/CloudStorage/GoogleDrive-omerulfaruk97@gmail.com/My Drive/MyReposDrive/obsidian_Notes/Landy Omer Re 1/av-dur-estimation/fitMain.py:609, in paramBootstrap(fitParams, nBoots)
#     605 initGuessEstimate = estimate_initial_guesses(simData[intensityVariable].values,
#     606                                             simData['num_of_chose_test'],
#     607                                             simData['total_responses'])
#     608 # fit the data to boot
# --> 609 bootFit = fitJoint(grouped_data=simData, initGuesses=initGuessEstimate)
#     611 # save
#     612 nBootParams.append(bootFit.x)
#
# File ~/Library/CloudStorage/GoogleDrive-omerulfaruk97@gmail.com/My Drive/MyReposDrive/obsidian_Notes/Landy Omer Re 1/av-dur-estimation/fitMain.py:414, in fitJoint(grouped_data, initGuesses)
#     409     bounds = [(0, 0.25)]*nLambda + [(-2, +2)]*nSensoryVar*nConflictVar + [(0.01, +2)]*nSensoryVar*nConflictVar
#     411 #print(f" len initGuesses: {len(initGuesses)}")
#     412
#     413 # Minimize negative log-likelihood
# --> 414 result = minimize(
#     415     nLLJoint,
#     416     x0=initGuesses,
#     417     args=(intensities, chose_tests, total_responses, conflicts, noise_levels),
#     418     bounds=bounds,
#     419     method='L-BFGS-B'  # Use L-BFGS-B for bounded optimization
#     420 )
#     422 return result
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_minimize.py:731, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     728     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     729                              **options)
#     730 elif meth == 'l-bfgs-b':
# --> 731     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     732                            callback=callback, **options)
#     733 elif meth == 'tnc':
#     734     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     735                         **options)
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_lbfgsb_py.py:407, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     401 task_str = task.tobytes()
#     402 if task_str.startswith(b'FG'):
#     403     # The minimization routine wants f and g at the current x.
#     404     # Note that interruptions due to maxfun are postponed
#     405     # until the completion of the current minimization iteration.
#     406     # Overwrite f and g:
# --> 407     f, g = func_and_grad(x)
#     408 elif task_str.startswith(b'NEW_X'):
#     409     # new iteration
#     410     n_iterations += 1
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:344, in ScalarFunction.fun_and_grad(self, x)
#     342     self._update_x(x)
#     343 self._update_fun()
# --> 344 self._update_grad()
#     345 return self.f, self.g
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:306, in ScalarFunction._update_grad(self)
#     304 if self._orig_grad in FD_METHODS:
#     305     self._update_fun()
# --> 306 self.g = self._wrapped_grad(self.x, f0=self.f)
#     307 self.g_updated = True
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:47, in _wrapper_grad.<locals>.wrapped1(x, f0)
#      45 def wrapped1(x, f0=None):
#      46     ncalls[0] += 1
# ---> 47     return approx_derivative(
#      48         fun, x, f0=f0, **finite_diff_options
#      49     )
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:519, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     516     use_one_sided = False
#     518 if sparsity is None:
# --> 519     return _dense_difference(fun_wrapped, x0, f0, h,
#     520                              use_one_sided, method)
#     521 else:
#     522     if not issparse(sparsity) and len(sparsity) == 2:
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:592, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     590     x1[i] += h[i]
#     591     dx = x1[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 592     df = fun(x1) - f0
#     593 elif method == '3-point' and use_one_sided[i]:
#     594     x1[i] += h[i]
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:470, in approx_derivative.<locals>.fun_wrapped(x)
#     467 if xp.isdtype(x.dtype, "real floating"):
#     468     x = xp.astype(x, x0.dtype)
# --> 470 f = np.atleast_1d(fun(x, *args, **kwargs))
#     471 if f.ndim > 1:
#     472     raise RuntimeError("`fun` return value has "
#     473                        "more than 1 dimension.")
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:20, in _wrapper_fun.<locals>.wrapped(x)
#      16 ncalls[0] += 1
#      17 # Send a copy because the user may overwrite it.
#      18 # Overwriting results in undefined behaviour because
#      19 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 20 fx = fun(np.copy(x), *args)
#      21 # Make sure the function returns a true scalar
#      22 if not np.isscalar(fx):
#
# File ~/Library/CloudStorage/GoogleDrive-omerulfaruk97@gmail.com/My Drive/MyReposDrive/obsidian_Notes/Landy Omer Re 1/av-dur-estimation/fitMain.py:433, in nLLJoint(params, delta_dur, responses, total_responses, conflicts, noise_levels)
#     430     lam[i], mu[i], sigma[i] = getParams(params, conflicts[i], noise_levels[i], nLambda, nSigma)
#     432 # Vectorized psychometric function
# --> 433 p = lam / 2 + (1 - lam) * norm.cdf((delta_dur - mu) / sigma)
#     434 epsilon = 1e-9
#     435 p = np.clip(p, epsilon, 1 - epsilon)
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/stats/_distn_infrastructure.py:2112, in rv_continuous.cdf(self, x, *args, **kwds)
#    2110 x = np.asarray((x - loc)/scale, dtype=dtyp)
#    2111 cond0 = self._argcheck(*args) & (scale > 0)
# -> 2112 cond1 = self._open_support_mask(x, *args) & (scale > 0)
#    2113 cond2 = (x >= np.asarray(_b)) & cond0
#    2114 cond = cond0 & cond1
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/stats/_distn_infrastructure.py:1022, in rv_generic._open_support_mask(self, x, *args)
#    1021 def _open_support_mask(self, x, *args):
# -> 1022     a, b = self._get_support(*args)
#    1023     with np.errstate(invalid='ignore'):
#    1024         return (a < x) & (x < b)
#
# File /opt/miniconda3/envs/mathmod/lib/python3.11/site-packages/scipy/stats/_distn_infrastructure.py:994, in rv_generic._get_support(self, *args, **kwargs)
#     991         cond = logical_and(cond, (asarray(arg) > 0))
#     992     return cond
# --> 994 def _get_support(self, *args, **kwargs):
#     995     """Return the support of the (unscaled, unshifted) distribution.
#     996
#     997     *Must* be overridden by distributions which have support dependent
#    (...)
#    1012         shape parameters.
#    1013     """
#    1014     return self.a, self.b
#
# KeyboardInterrupt:

# %%
plot_conflict_vs_pse(fit, allBootedFits)
